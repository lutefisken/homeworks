# %%
import json, os
import pandas as pd
from nltk.corpus import stopwords
import numpy as np
from pymorphy2 import MorphAnalyzer
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
morph = MorphAnalyzer()
stops = set(stopwords.words('russian'))

# %%
# import nltk
# nltk.download('stopwords')

# %%
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# ## Данные

# %% [markdown]
# Возьмем данные вот отсюда - https://github.com/mannefedov/ru_kw_eval_datasets Там лежат 4 датасета (статьи с хабра, с Russia Today, Независимой газеты и научные статьи с Киберленинки). Датасет НГ самый маленький, поэтому возьмем его в качестве примера.

# %%
# скачаем данные в папке data и распакуем их
PATH_TO_DATA = 'ng'

# %%
files = [os.path.join(PATH_TO_DATA, file) for file in os.listdir(PATH_TO_DATA)]

# %% [markdown]
# Объединим файлы в один датасет.

# %%
data = pd.concat([pd.read_json(file, lines=True) for file in files], axis=0, ignore_index=True)

# %%
data.shape #куда-то пропали 11 строчек по сравнению с исходной тетрадкой, что странно
# Out:
# (1987, 5)

# %%
print(files) #вроде бы как оба файла на месте
# Out:
# ['ng/ng_0.jsonlines', 'ng/ng_1.jsonlines']

# %%
data.head(3) #здесь все выглядит правильно
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    content  \
# 0  Многие интересуются, зачем нужна «Яблоку» молодежная фракция? Основной задачей «Молодежного «Яблока» является привлечение молодых людей к участию в выборах и деятельности партии. «Молодежное «Яблоко» работает более чем в 10 регионах. Единого руководства у нас нет, но мы стараемся координировать свою деятельность и периодически проводим акции на федеральном уровне.\nМы ведем борьбу с обязательным воинским призывом. Военный – это профессия, а не обязанность. Молодые люди вправе сами распоряжаться своей жизнью и не терять целый год, отдавая государству «долг», который они у него не занимали. По мнению одного из ведущих специалистов в области оборонной политики Алексея Арбатова, переход на контрактную армию будет стоить лишь 2% военного бюджета.\nТакже на федеральном уровне «Молодежное «Яблоко» проводило акции за освобождение политзаключенных и против вмешательства России во внутреннюю политику Украины.\nРасскажу о московских активистах. Виктору Петрунину – 19 лет, он пришел к нам боль...
# 1  Вчера «Газпром» снизил верхнюю планку прогноза собственной добычи газа в 2020 году. Через 12 лет концерн собирается добывать около 620–640 млрд. куб. м в год. При этом общее производство газа в стране, по расчетам холдинга, должно достичь 940 млрд. куб. м. Иными словами, треть добываемого объема, по мнению холдинга, должны будут обеспечить независимые производители. Эксперты не верят, что независимые компании смогут выйти на такие объемы добычи. Если расчеты «Газпрома» не оправдаются, то под ударом окажутся отечественные предприятия и население, которым придется сокращать потребление и смириться с новым витком цен. Иных путей покрытия возможного дефицита газа нет, так как вряд ли холдинг разорвет уже заключенные контракты на экспорт газа в другие страны. \n«Газпром» к 2020 году планирует добывать 620–640 млрд. куб. м газа, сообщил вчера на форуме «ТЭК России в ХХI веке» глава управления по добыче газа, газового конденсата и нефти холдинга Валерий Минликаев. Тем самым он уточнил пре...
# 2  Долголетний труд Евгения Витковского на ниве перевода, а также в качестве редактора и антологиста известен многим. Но не все знают его как поэта и прозаика. В этом году уже вышла составленная им и Еленой Кистеровой антология  «Раздол туманов: Страницы шотландской гэльской поэзии XVII–XX вв.», а в апреле запланирован выход его романа «Протей, или Византийский кризис» (отрывок из романа читайте на с. 12). С \n побеседовал \n– Одна из таких книг только что вышла – «Раздол туманов. Страницы шотландской гэльской поэзии XVII–XX веков». Это стихи 29 поэтов, все в переводе с оригинала – моем и Елены Кистеровой. Работа заняла 10 лет, включая изучение языка. Она была упоительно интересной: до нас переводов из этой поэзии на русский не было вовсе. Сейчас должен выйти том стихотворений канадского классика Роберта Уильяма Сервиса, «канадского Киплинга», около 300 стихотворений. Кроме того, в Петербурге в производстве наш огромный трехтомный плод совместной работы – антология «Франция в сердце»....
#
#                                                                                                                                                                                                                                                         keywords  \
# 0                                                                                                                                                                                                                          [яблоко, молодежь, молодежное яблоко]
# 1                                                                                                                                                                                                                                                 [газпром, газ]
# 2  [франсуа рабле, сервантес, шекспир, конан дойл, михаил булгаков, александр грин, борхес, босх, маркес, герман гессе, голландская живопись, гаргантюа и пантагрюэль, дон кихот, мастер и маргарита, москва, россия, история, поэзия, шотландия, баллада, пере]
#
#                                                                                                                                     summary  \
# 0
# 1
# 2  Евгений Витковский о том, как Босх протягивает руку Шекспиру, \r\nи оба танцуют в пламени пожара в охваченном чумой средневековом городе
#
#                                                                  title  \
# 0  "Молодежное "Яблоко": оппозиционная деятельность становится опасной
# 1                                         "Газпрома" на всех не хватит
# 2                          Бесконечная партия в четырехмерные  шахматы
#
#                                                           url
# 0  http://www.ng.ru/ng_politics/2017-04-18/11_6976_apple.html
# 1        http://www.ng.ru/economics/2008-04-03/1_gazprom.html
# 2    http://www.ng.ru/person/2018-03-22/10_927_vitkovsky.html

# %% [markdown]
# Каждой статье приписано какое-то количество ключевых слов. Допустим, что это единственно правильный набор ключевых слов (что конечно не так, но других данных у нас нет). Наша задача - придумать как извлекать точно такой же список автоматически.
# Зададим несколько метрик, по которым будем определять качество извлекаемых ключевых слов - точность, полноту, ф1-меру и меру жаккарда.

# %%
def evaluate(true_kws, predicted_kws):
    assert len(true_kws) == len(predicted_kws)
    
    precisions = []
    recalls = []
    f1s = []
    jaccards = []
    
    for i in range(len(true_kws)):
        true_kw = set(true_kws[i])
        predicted_kw = set(predicted_kws[i])
        
        tp = len(true_kw & predicted_kw)
        union = len(true_kw | predicted_kw)
        fp = len(predicted_kw - true_kw)
        fn = len(true_kw - predicted_kw)
        
        if (tp+fp) == 0:
            prec = 0
        else:
            prec = tp / (tp + fp)
        
        if (tp+fn) == 0:
            rec = 0
        else:
            rec = tp / (tp + fn)
        if (prec+rec) == 0:
            f1 = 0
        else:
            f1 = (2*(prec*rec))/(prec+rec)
            
        jac = tp / union
        
        precisions.append(prec)
        recalls.append(rec)
        f1s.append(f1)
        jaccards.append(jac)
    print('Precision - ', round(np.mean(precisions), 2))
    print('Recall - ', round(np.mean(recalls), 2))
    print('F1 - ', round(np.mean(f1s), 2))
    print('Jaccard - ', round(np.mean(jaccards), 2))

# %% [markdown]
# Проверим, что всё работает как надо.

# %%
evaluate(data['keywords'], data['keywords'])
# Out:
# Precision -  1.0
# Recall -  1.0
# F1 -  1.0
# Jaccard -  1.0

# %% [markdown]
# # Тупое решение.

# %% [markdown]
# Давайте не будем думать, а попробуем сразу придумать какое-то решение.

# %% [markdown]
# Возьмем первые 5 слов из заголовка.

# %%
evaluate(data['keywords'], data['title'].apply(lambda x: x.lower().split()[:5]))
# Out:
# Precision -  0.06
# Recall -  0.05
# F1 -  0.05
# Jaccard -  0.03

# %% [markdown]
# Или 10.

# %%
evaluate(data['keywords'], data['title'].apply(lambda x: x.lower().split()[:10]))
# Out:
# Precision -  0.06
# Recall -  0.06
# F1 -  0.05
# Jaccard -  0.03

# %% [markdown]
# Теперь попробуем взять самые частотные слова.

# %%
evaluate(data['keywords'], data['content'].apply(lambda x: 
                                                 [x[0] for x in Counter(x.lower().split()).most_common(10)]))
# Out:
# Precision -  0.02
# Recall -  0.04
# F1 -  0.02
# Jaccard -  0.01

# %% [markdown]
# Или вообще рандомные слова.

# %%
evaluate(data['keywords'], data['content'].apply(lambda x: 
                                                 np.random.choice(list(set(x.lower().split())), 10)))
# Out:
# Precision -  0.0
# Recall -  0.01
# F1 -  0.01
# Jaccard -  0.0

# %% [markdown]
# Теперь давайте посмотрим, что вообще извлекается.

# %%
data['title'].apply(lambda x: x.lower().split()[:10]).head(10)
# Out:
# 0                         ["молодежное, "яблоко":, оппозиционная, деятельность, становится, опасной]
# 1                                                                 ["газпрома", на, всех, не, хватит]
# 2                                                   [бесконечная, партия, в, четырехмерные, шахматы]
# 3    [экс-депутат,, осужденная, за, фальсификацию, выборов,, оказалась, членом, "боевого, братства"]
# 4                               [новая, москва, останется, территорией, экологической, безопасности]
# 5                                [f1., гран-при, сша, прошел, без, четырех, машин, и, со, «стопкой»]
# 6                                          [100, ведущих, политиков, россии, в, феврале, 2018, года]
# 7                                               [закон, "о, культуре", принимают, на, фоне, арестов]
# 8                                    [насколько, реальна, газовая, подоплека, сирийского, конфликта]
# 9                                  [фсб:, в, калужской, области, задержаны, четверо, участников, иг]
# Name: title, dtype: object

# %%
data['content'].apply(lambda x: [x[0] for x in Counter(x.lower().split()).most_common(10)]).head(10)
# Out:
# 0                                                      [в, и, на, не, что, –, его, «молодежное, с, это]
# 1                                                            [в, и, на, –, млрд., куб., по, к, газа, м]
# 2                                                                 [в, –, и, не, я, но, что, это, на, с]
# 3                                                       [в, на, и, ким, по, –, что, видео, он, зинаиды]
# 4                                              [в, и, на, новой, площадью, москвы, –, развития, с, для]
# 5                                                             [в, на, и, не, с, но, уже, что, у, гонки]
# 6                                                  [на, в, (с, место)., и, рф, позиции, влияние, по, с]
# 7                                                        [в, и, –, по, с, культуре, не, из, будет, как]
# 8                                                              [в, и, на, с, что, для, по, –, не, газа]
# 9    [в, рф, террористической, организации, задержаны, –, четверо, участников, запрещенной, «исламское]
# Name: content, dtype: object

# %% [markdown]
# Когда извлекаются частотные слова, то список почти полностью состоит из всяких стоп-слов. Также из-за плохой токенизации некоторые слова в обоих списках - пунктуация или слова с пунктуацией на концах. К тому же извлекаемые слова ненормализованы, а правильные ключевые слова - наоборот.

# %% [markdown]
# ## Токенизация, удаление стоп-слов и нормализация.

# %%
from string import punctuation
from nltk.corpus import stopwords
punct = punctuation+'«»—…“”*№–'
stops = set(stopwords.words('russian'))

def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0].normal_form for word in words if word and word not in stops]

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
data['title_norm'] = data['title'].apply(normalize)

# %%
data['title_norm'].head(10)
# Out:
# 0            [молодёжный, яблоко, оппозиционный, деятельность, становиться, опасный]
# 1                                                                 [газпром, хватить]
# 2                                      [бесконечный, партия, четырехмерный, шахматы]
# 3    [экс-депутат, осудить, фальсификация, выбор, оказаться, член, боевой, братство]
# 4                 [новый, москва, остаться, территория, экологический, безопасность]
# 5                         [f1, гран-при, сша, пройти, четыре, машина, стопка, штраф]
# 6                                [100, ведущий, политик, россия, февраль, 2018, год]
# 7                                           [закон, культура, принимать, фон, арест]
# 8                     [насколько, реальный, газовый, подоплёка, сирийский, конфликт]
# 9                       [фсб, калужский, область, задержать, четверо, участник, иго]
# Name: title_norm, dtype: object

# %% [markdown]
# Попробуем те же самые методы.

# %%
# топ 10 частотных слов статьи
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.11
# Recall -  0.22
# F1 -  0.14
# Jaccard -  0.08

# %%
evaluate(data['keywords'],data['title_norm'].apply(lambda x: x[:10]))
# Out:
# Precision -  0.13
# Recall -  0.13
# F1 -  0.12
# Jaccard -  0.07

# %% [markdown]
# Качество сильно улучшилось! Можно теперь ещё раз посмотреть, что плохого извлекается.

# %%
data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(20)
# Out:
# 0                         [яблоко, молодёжный, который, акция, год, активист, это, деятельность, политика, наш]
# 1                               [миллиард, газа, год, куб, метр, газпром, добыча, 2020, должный, производитель]
# 2                                              [год, это, книга, роман, тот, писать, выйти, один, мир, перевод]
# 3                                    [ким, зинаида, видео, год, журналист, суд, дело, бывший, футиный, который]
# 4                         [площадь, территория, новый, москва, га, который, столица, тинао, парковый, развитие]
# 5                                  [гонка, который, команда, место, позиция, два, один, из-за, круг, чемпионат]
# 6                        [место, влияние, рф, позиция, глава, россия, президент, сергей, политический, рейтинг]
# 7                 [культура, закон, который, сфера, стд, разработать, концепция, проект, изменение, сообщество]
# 8                              [газопровод, сирия, год, турция, газа, россия, европа, катар, который, турецкий]
# 9     [участник, рф, террористический, организация, задержать, цос, четверо, запретить, исламский, государство]
# 10                            [тихон, стихомант, это, журибеда, старик, время, казак, сэмена, говорить, что-то]
# 11                          [жильё, метр, кв, год, миллион, жилищный, население, строительство, спрос, прогноз]
# 12                   [российский, театр, зритель, стать, кино, год, получить, хороший, результат, исследование]
# 13                      [фестиваль, революция, фильм, ленин, награда, хороший, один, сахалин, посмотреть, роль]
# 14                 [вечер, фёдоров, балашов, книга, который, виктория, произведение, женщина, женский, главный]
# 15        [который, сирийский, переговоры, резолюция, оон, франция, сторона, макрон, французский, гуманитарный]
# 16                                 [рф, суд, кс, запрос, постановление, право, человек, бывший, акционер, юкос]
# 17                 [электромобиль, год, тысяча, кобальт, который, компания, аккумулятор, это, автомобиль, цена]
# 18                              [хороший, фильм, оскар, год, один, главный, стать, который, женщина, церемония]
# 19                       [сабина, нюрбургринг, трасса, fia, wtcc, участие, пилотесса, шмитц, гонка, автомобиль]
# Name: content_norm, dtype: object

# %% [markdown]
# Ещё остались некоторые стоп-слова. Вместо того, чтобы расширять список, давайте попробуем выкинуть несуществительные.

# %%
def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0] for word in words if word and word not in stops]
    words = [word.normal_form for word in words if word.tag.POS == 'NOUN']

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.13
# Recall -  0.25
# F1 -  0.16
# Jaccard -  0.1

# %% [markdown]
# Ещу улучшения!

# %%
data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(10)
# Out:
# 0        [яблоко, акция, год, активист, деятельность, политика, власть, задача, молодая, человек]
# 1               [миллиард, газа, год, куб, метр, газпром, добыча, производитель, страна, прогноз]
# 2                [год, книга, роман, мир, перевод, стихотворение, читатель, жанр, поэзия, работа]
# 3                     [ким, зинаида, видео, год, журналист, суд, дело, рубль, процесс, заседание]
# 4                   [площадь, территория, москва, га, столица, тинао, развитие, парка, парк, год]
# 5                    [гонка, команда, место, позиция, круг, чемпионат, пилот, бокс, заезд, льюис]
# 6               [место, влияние, рф, позиция, глава, россия, президент, сергей, рейтинг, участие]
# 7    [культура, закон, сфера, концепция, проект, изменение, сообщество, услуга, учреждение, дело]
# 8                    [газопровод, сирия, год, турция, газа, россия, европа, катар, поток, проект]
# 9                 [участник, рф, организация, государство, область, центр, связь, фсб, март, год]
# Name: content_norm, dtype: object

# %% [markdown]
# Не очень значимые слова все ещё остались. Давайте попробуем отсеять стоп-слова с помощью tfidf.

# %% [markdown]
# Воспользуемся TfidfVectorizer.

# %%
data['content_norm_str'] = data['content_norm'].apply(' '.join)

# %%
# можно заодно сделать нграммы
tfidf = TfidfVectorizer(ngram_range=(1,2), min_df=5)

# %%
tfidf.fit(data['content_norm_str'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=5,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}

# %% [markdown]
# Преобразуем наши тексты в векторы, где на позиции i стоит tfidf коэффициент слова i из словаря.

# %%
texts_vectors = tfidf.transform(data['content_norm_str'])

# %% [markdown]
# Отсортируем векторы текстов по этим коэффициентам и возьмем топ-10.

# %%
# сортировка по убыванию, поэтому нужно развернуть список
keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-11:-1]]

# %%
keywords[:3]
# Out:
# [['яблоко',
#   'активист',
#   'акция',
#   'дарья',
#   'деятельность',
#   'молодая человек',
#   'политика',
#   'виктор',
#   'тимур',
#   'репрессия'],
#  ['миллиард куб',
#   'куб метр',
#   'куб',
#   'газпром',
#   'газа',
#   'миллиард',
#   'добыча',
#   'добыча газа',
#   'метр',
#   'холдинг'],
#  ['роман',
#   'книга',
#   'жанр',
#   'стихотворение',
#   'читатель',
#   'перевод',
#   'год',
#   'поэзия',
#   'произведение',
#   'том']]

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.13
# Recall -  0.25
# F1 -  0.16
# Jaccard -  0.09

# %% [markdown]
# Результат ещё немного улучшился. Немного подросла точность. Теперь вместо стоп-слов в ключевые попадают имена и все такое. Иногда это хорощо, а иногда нет (собянин - может быть ключевым словом, а дарья - вряд ли)

# %% [markdown]
# Возьмем этот результат за baseline.

# %% [markdown]
# Precision -  0.13
# Recall -  0.24
# F1 -  0.16
# Jaccard -  0.09

# %%
# во-первых, видно, что несуществительных все-таки много (издать, это...) 
#нужен другой pos-tagger. rnnmorph работает слишком долго
from pymystem3 import Mystem

# %%
data['content_norm'] #как было до майстема
# Out:
# 0                                                                                     [яблоко, фракция, задача, яблоко, привлечение, молодая, человек, участие, выборы, деятельность, партия, яблоко, регион, руководство, деятельность, акция, уровень, борьба, призыв, военный, профессия, обязанность, молодая, человек, жизнь, год, государство, долг, мнение, специалист, область, политика, алексей, арбатов, переход, армия, военный, бюджет, уровень, яблоко, акция, освобождение, политзаключённый, вмешательство, россия, политика, украина, активист, виктор, петрунин, год, год, москва, семья, взгляд, виктор, детство, политика, виктор, власть, крым, война, украина, убийство, борис, немцов, сторона, школа, сила, смена, власть, россия, дарья, новичкова, влияние, преподаватель, обществознание, ситуация, страна, искренность, заинтересованность, вопрос, дарья, материал, сми, время, наблюдение, позиция, образ, команда, единомышленник, пример, ровесник, дарья, яблоко, яблоко, клуб, рамка, лекция, кинопоказ, ...]
# 1                                                                                                                                                                 [газпром, планка, прогноз, добыча, газа, год, год, концерн, миллиард, куб, метр, год, производство, газа, страна, расчёт, холдинг, миллиард, куб, метр, слово, треть, объём, мнение, холдинг, производитель, эксперт, компания, объём, добыча, расчёт, газпром, удар, предприятие, население, потребление, виток, цена, путь, покрытие, дефицит, газа, холдинг, заключённый, контракт, экспорт, газа, страна, газпром, год, миллиард, куб, метр, газа, форум, тэк, россия, век, глава, управление, добыча, газа, конденсат, нефть, холдинг, валерий, минликай, прогноз, добыча, газа, прошлое, год, зампред, правление, концерн, александр, ананенков, слово, ананенков, газпром, год, миллиард, куб, метр, год, прогноз, газпром, стратегия, правительство, добыча, газа, холдинг, представление, минпромэнерго, минэкономразвития, добыча, газа, россия, год, уровень, ...]
# 2                                                                                                                                        [труд, евгений, витковский, нива, перевод, качество, редактор, антологист, поэт, прозаик, год, елена, кистеров, антология, раздол, туманов, страница, поэзия, век, апрель, выход, роман, протей, кризис, отрывок, роман, книга, раздол, туманов, страница, поэзия, век, стих, поэт, перевод, оригинал, елена, кистеров, работа, год, изучение, язык, перевод, поэзия, стихотворение, классика, роберт, уильям, сервис, киплинга, стихотворение, петербург, производство, плод, работа, антология, франция, сердце, стихотворение, век, участник, семинар, перевод, работа, год, деньга, культура, борьба, коррупция, план, перевод, велик, комплекс, книга, сборник, классика, дидерик, йоханнес, оппермана, редактор, год, 1990-е, возможность, читатель, год, главное, редактор, издательство, год, престиж, бук, читатель, серия, рамка, книга, приключение, фантастика, детгиз, книга, серия, ...]
# 3                                                                                  [суд, слушание, дело, экс-депутат, дума, владивосток, зинаида, ким, председатель, участок, елена, сговор, фальсификация, результат, выборы, выборы, год, сентябрь, год, журналист, видео, ким, кандидат, список, собрание, край, молодая, человек, участок, визит, качество, вознаграждение, избиратель, рубль, начало, процесс, зинаида, ким, журналист, тон, видео, монтаж, адвокат, внимание, участник, процесс, характеристика, подсудимая, руководитель, организация, братство, приморье, член, подсудимая, зинаида, ким, список, знак, 70-летие, победа, война, 25-летие, вывод, войско, афганистан, 20-летие, мчс, ход, заседание, адвокат, алексей, клецкина, судья, экспертиза, видео, аудиозапись, процесс, качество, доказательство, вина, ким, защитник, сомнение, подлинность, экспертиза, обвинитель, прошение, защитник, судья, позиция, представитель, прокуратура, заседание, дело, зинаида, ким, елена, свидетель, редактор, издание, ...]
# 4                                                                                    [год, столица, размер, результат, присоединение, часть, территория, область, появление, москва, мегаполис, потенциал, рост, власть, новое, обязательство, распоряжение, земля, площадь, заключённый, мкада, состав, москва, троицкий, округа, тинао, регион, особенность, процесс, освоение, власть, столица, год, тинао, принцип, развитие, тинао, формирование, среда, жильё, инфраструктура, парка, обследование, эксперт, забота, лесна, массив, москва, площадь, тысяча, га, привеcть, порядок, разнообразие, москва, план, столица, граница, территория, территория, зона, полоса, леса, мусор, борьба, жук-короед, леса, регион, строительство, подъезд, расчистка, пруд, водоём, территория, экология, регион, схема, площадь, десяток, направленность, власть, москва, год, округа, портал, комплекс, политика, строительство, столица, ссылка, глава, департамент, развитие, территория, столица, владимир, жидкина, слово, территория, га, ...]
# 5                                                                                                                                                                                       [этап, чемпионат, мир, автогонки, класс, состав, сша, автодром, остин, техас, пелетон, автомобиль, финиш, гонка, участие, болид, заезд, гран-при, сша, льюис, хэмилтон, место, нико, росберг, вакансия, ступенька, подиум, дэниэл, даниил, квёнок, гонка, пилот, строчка, протокол, прокол, колесо, конец, заезд, чемпионат, интрига, смысл, титул, чемпион, мир, пилот, команда, кубок, конструктор, новость, гонка, стан, команда, команда, заявка, участие, сезон, гонка, сезон, аба-даби, переговоры, старое, владелец, команда, завершение, круг, гонка, авария, исполнение, серхио, перес, крик, карамб, адриан, сутил, машина, сутил, перес, подвеска, бокс, судья, вердикт, балл, позиция, старт, гонка, машина, сход, штрафник, жан-эрик, вернь, гутьеррес, пастор, мальдонадо, зачёт, балл, маркус, эриксон, пастор, мальдонадо, победа, ...]
# 6                                                                                                                                                                      [лидер, рейтинг, владимир, путин, фактор, позиция, политик, февраль, гонка, работа, площадка, россия, форум, сочи, рубеж, конференция, безопасность, анонсирование, развитие, проект, скандал, рейтинг, февраль, полпред, президент, рф, округа, алексей, гордеев, 95-е, место, фон, обострение, ситуация, сирия, влияние, глава, минобороны, рф, сергей, шойгу, 5-го, 3-е, место, итог, визит, делегация, руководитель, спецслужба, сша, позиция, директор, фсб, александр, бортников, 9-го, 8-е, место, глава, свр, сергей, нарышкина, 41-го, 40-е, место, сообщение, участие, совбез, рф, николай, патрушев, операция, выявление, канал, наркотрафик, аргентина, россия, влияние, 17-го, 15-е, место, фон, обсуждение, реформирование, сфера, влияние, вице-премьер, рф, вопрос, ольга, голодец, 31-го, 29-е, место, глава, палата, рф, татьяна, голиков, 23-го, ...]
# 7                                                                        [начало, февраль, перечень, поручение, президент, культура, искусство, руководство, действие, задача, декабрь, первое, концепция, проект, закон, культура, внесение, изменение, акт, срок, март, разработка, проект, закон, июль, госдума, проект, закон, внесение, изменение, система, закупка, учёт, особенность, сфера, культура, время, арест, создатель, платформа, обвинение, мошенничество, ситуация, точка, сообщество, изменение, принцип, подход, год, задача, концепция, новое, закон, культура, сфера, услуга, поправка, кодекс, разговор, заместитель, председатель, рф, союз, деятель, геннадий, смирнов, год, председатель, комиссия, культура, палата, первое, созыв, александр, калягин, доклад, культура, будущее, россия, взгляд, инициатива, проблема, законодательство, учёт, специфика, искусство, культура, сфера, услуга, услуга, человек, вопрос, рамка, законодательство, зампред, форма, учреждение, культура, характер, деятельность, ...]
# 8                                                                                                                          [военный, эксперт, доктор, военный, наука, владимир, попов, газета, сантиметр, статья, название, россия, контроль, северо-восток, сирия, внимание, формирование, военный, союз, сирия, предпосылка, транспортировка, территория, углеводород, полуостров, турция, европа, газопровод, поток, рф, мотив, ввод, группировка, сирия, высказывание, военный, эксперт, неточность, читатель, заблуждение, смысл, дело, подоплёка, конфликт, счёт, указание, редактор, газета, проблема, связь, конфликт, сирия, интерес, россия, печать, сирия, европа, газ, катар, иран, версия, саудовец, катарец, асад, год, идея, газопровод, катар, год, тегеран, меморандум, намерение, транзит, газа, европа, ирак, турция, вид, завод, сжижение, газа, берег, море, газопровод, проект, газопровод, поставка, газа, месторождение, парс, вод, катар, иран, территория, турция, газопровод, набукко, проект, цель, снабжение, ...]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [участник, рф, организация, государство, область, центр, связь, фсб, март, год, участник, ячейка, исламист, житель, округа, эмиссар, прошедшее, подготовка, территория, сирия, сообщение, данные, рф, организация, деятельность]
# 10                                                                                                                                                                                                                  [поезд, платформа, вагон, продажа, билет, речь, время, время, состав, ход, горилка, сэмена, журибеда, окно, пейзаж, предместье, руина, здание, часть, окружение, дорога, зрелище, запустение, тихон, дежнев, казак, горилка, журибеда, живой, человек, людин, еда, як, гвоздь, пассатижи, состав, поезд, вагон, стекло, купе, фигура, пассажир, полка, рука, дверь, купе, проём, клуб, дым, тихон, щёлка, стол, девушка, убор, чёрный, перо, соска, колечко, живот, незнакомка, тихон, журибеда, тамбур, проход, вагон, галерея, окрестность, ковыль, красных, собака, поезд, морда, креозот, воздух, нога, голов, состав, искра, чёрный, труба, локомотив, командир, шалман, журибеда, кафе, край, цистерна, половина, стен, бок, окошко, отверстие, люк, потолок, ворота, труба, полумрак, столик, пассажир, хозяин, ...]
# 11                                                                                                                                                                [год, россия, миллион, метр, жильё, прогноз, вторник, александр, плутник, глава, агентство, кредитование, аижк, день, дом.рф, послание, собрание, президент, владимир, путин, задача, объём, строительство, раз, миллион, метр, год, цель, стратегия, развитие, сфера, год, минстрой, прогноз, центр, разработка, темп, рост, доход, население, эксперт, наличие, спрос, жильё, правительство, реализация, послание, собрание, повестка, день, пункт, увеличение, строительство, премьер, дмитрий, медведев, александр, плутник, компания, дом.рф, владимир, путин, ход, послание, строительство, рф, раз, миллион, метр, жильё, год, миллион, семья, новое, жильё, страна, миллион, метр, жильё, год, плутник, точка, зрение, расчёт, выход, миллион, метр, жильё, год, перспектива, жильё, учёт, страна, миллион, метр, качество, жильё, плутник, вопрос, привлечение, ...]
# 12                                                                            [неделя, развитие, история, увольнение, режиссёр, юрий, бутусов, пост, руководитель, театр, ленсовет, заявление, уход, связь, блокировка, попытка, ряд, изменение, структура, коллектив, комитет, культура, конфликт, сторона, директор, комментарий, сми, глава, константин, сухенко, мера, манера, бутусов-чиновник, мрачность, абсурдизм, ведомство, ленсовет, театр, качество, образец, деятельность, театр, антреприза, андрей, миронов, григорий, козлов, зритель, живой, акция, поддержка, режиссёр, четверг, театр, жизнь, олег, табаков, друг, коллега, родственник, ученик, цыплёнок, табак, панихида, президент, владимир, путин, ольга, голодец, владимир, член, правительство, сотня, зритель, день, гроб, цвета, дань, уважение, артист, табаков, кладбище, мид, прекращение, деятельность, территория, россия, совет, связь, неурегулированность, статус, шаг, мера, москва, ответ, высылка, дипломат, великобритания, институция, множество, ...]
# 13                                                                                                             [фестиваль, фильм, утро, родина, середина, март, остров, сахалин, инициатива, попытка, суверенность, жанр, телефильм, 90-е, культура, качество, произведение, экранизация, классика, зритель, офф-программа, фестиваль, старое, телеспектакль, простор, интернет, канал, культура, награда, телесмотр, лотос, жюри, председательство, николай, досталя, продюсер, фильм, оптимист, валерий, антон, режиссёр, владимир, котт, работа, картина, пётр, лещенко, сценарий, фильм, звезда, эстрада, 30-40-ха, константин, роль, эдуард, артист, награда, роль, троцкий, фильм, работа, троцкий, номинация, работа, оператор, сергей, трофим, николай, богачев, улугбек, хамраев, байопик, юбилей, революция, телеэкран, афиша, сериал, демон, революция, фильм, награда, максим, матвеев, роль, план, жюри, образ, дуэт, роль, картина, анна, каренин, награда, елизавета, приз, фестиваль, вклад, развитие, кинематограф, марк, ...]
# 14                                                                                                                                         [прошедшее, день, вечер, магазин, библио-глобус, роман, героиня, писательница, виктория, балашов, елена, фёдоров, вечер, поэт, александр, чистяков, начало, вечер, произведение, женщина, мужчина, внимание, деталь, туалет, платье, украшение, оружие, женщина, мир, авторы-женщина, псевдоним, даба, имя, фёдоров, читатель, книга, виктория, балашов, тема, мир, место, солнце, мужчина-писатель, женщина, круг, дополнение, пейзаж, факт, балашов, книга, роль, женщина, писатель, созидание, строка, фёдоров, мысль, вода, грусть, крыло, ярка, тенденция, литература, вплетение, строка, произведение, елена, фёдоров, приём, вопрос, герой, стих, герой, герой, книга, марин, жюли, любовь, дама, форма, вечер, вопрос, число, влияние, знание, язык, уровень, произведение, лингвист, образование, виктория, балашов, язык, общение, человек, страна, масса, материал, писатель, книга, ...]
# 15                                                                                                                          [выполнение, резолюция, совет, безопасность, оон, прекращение, огонь, сирия, переговоры, глава, мид, рф, сергей, лавров, коллега, жан-ива, дриана, москва, франция, роль, военный, этап, кризис, париж, механизм, контроль, режим, тишина, выполнение, резолюция, дриана, итог, переговоры, лавров, резолюция, оон, база, затишье, течение, день, возможность, помощь, эвакуация, слово, министр, франция, необходимость, сторона, конфликт, перемирие, конвой, район, париж, механизм, контроль, соблюдение, перемирие, приезд, дриана, столица, пора, пост, министр, дело, республика, качество, этап, визит, президент, франция, эмманюэль, макрон, москва, май, год, выбор, россия, переговоры, президент, наполнение, договорённость, версаль, прорыв, отношение, лавров, пункт, повестка, визит, макрон, кризис, настоящее, время, связь, операция, сила, дамаск, гута, оппозиция, анклав, формирование, ...]
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [запрос, министерство, юстиция, рф, повод, возможность, исполнение, постановление, суд, право, человек, присуждение, компенсация, акционер, юкос, суд, база, суд, изучение, решение, судья, принятие, запрос, рассмотрение, отказ, минюст, просьба, соответствие, конституция, решение, еспч, выплата, польза, акционер, юкос, миллиард, евро, минюст, обязательство, рф, постановление, применение, еспч, положение, конвенция, защита, право, человек, свобода, истолкование, расхождение, конституция, рф, ведомство]
# 17                                                                                          [рынок, электромобиль, тенденция, развитие, статистика, исследование, агентство, год, продажа, электромобиль, сравнение, год, миллион, штука, темп, удвоение, число, электромобиль, полгода, подсчёт, электромобиль, гибрид, миллион, число, отношение, автомобиль, электрокар, парк, планета, темп, рост, показатель, рекорд, год, электромобиль, миллион, итог, год, темп, миллион, электрокар, год, конец, год, год, китай, сша, количество, транспорт, тысяча, тысяча, единица, год, доля, китай, парка, электромобиль, интерес, электротранспорт, ситуация, страна, гражданин, руководство, цель, улучшение, состояние, среда, сторона, электротранспорт, программа, транспорт, электричество, марка, китай, мир, энтузиаст, конец, эра, двигатель, эксперт, издание, статья, аналитика, завершение, история, машина, топливо, автор, декабрь, год, газета, ум, процесс, лошадь, средство, движение, транспорт, поиск, решение, редакция, ...]
# 18                                                                                                                                           [гильермо, торо, год, год, мужчина, женщина, рыба, монолог, церемония, вручение, премия, оскар, джимми, киммел, форма, вода, любовь, девушка, ихтиандра, итог, фильм, год, целое, триумфатор, вечер, сумма, статуэтка, разговор, право, женщина, неправомерность, домогательство, дискриминация, тема, церемония, фильм, награда, скандал, церемония, чёрный, наряд, золото, глобус, эмма, стоун, платье, костюм, минимум, поддержка, движение, харассмент, время, значок, поддержка, движение, запрет, продажа, ношение, оружие, количество, речь, шутка, тема, речь, киммел, статуэтка, оскар, образ, мужчина, рука, вид, пенис, харви, вайнштейн, академия, случай, история, организация, год, актёр, кармин, копия, фильм-номинант, тема, дискриминация, пол, национальность, цвета, кожа, нить, церемония, награда, основное, женщина, номинация, ролик, нарезка, картина, прошлое, год, ...]
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [организатор, чемпионат, мир, автогонки, класс, туринг, участие, телеведущая, пилотесса, сабина, шмитц, гонка, нюрбургринг, май, гонщица, руль, автомобиль, команда, рен, мюнниха, соревнование, германия, число, петля, ад, ада, время, дождь, сабина, пилотесса, отсутствие, опыт, управление, автомобиль, знание, трасса, шмитц, трасса, нюрбургринг, участие, гонка, час, нюрбургринг, такси, трасса, турист, правило, год, круг, автодром, сабина, дебют, соцсеть, телесюжет, представитель, инициатива, женщина, автоспорт]
# 20                                                                                                                                     [голос, дом, брюсов, музей, век, презентация, серия, автор, читатель, творчество, москвич, валерий, нарбикова, виктор, наталья, стеркин, адель, хаир, казань, галина, шаталов, саратов, поэзия, проза, драматургия, книга, рука, литература, рамка, текст, книга, артефакт, потребность, литература, вечер, единомышленник, друг, публикация, издание, повод, встреча, обсуждение, автор, друг, отрывок, книга, сопровождение, валерий, нарбикова, константин, воспоминание, встреча, размышление, путь, загадка, творчество, книга, художник, виктор, гоппа, событие, стиль, гоппа, шарм, серия, издание, книга, серия, голос, половина, год, россия, франция, год, чтение, год, год, литература, язык, россия, франция, событие, сфера, обмен, россия, участие, салон, качество, гость, тысяча, человек, пресс, писатель, участие, салон, большинство, читатель, перевод, мероприятие, 100-летие, ...]
# 21                                                                                             [эксперт, ситуация, театр, военный, действие, ключ, москва, дамаск, просчёт, вашингтон, сила, поддержка, коалиция, борьба, террорист, восток, юго-восток, страна, формирование, государство, иго, организация, россия, время, контратака, территория, война, завершение, сценарий, момент, формирование, отток, ополченец, район, сирия, африна, убыль, войско, вашингтон, состояние, предупреждение, командование, отказ, поддержка, формирование, курд, провинция, дейр-эз-зор, хасека, эффект, территория, сирия, дело, отряд, суть, армия, ирак, артиллерия, настоящее, время, огонь, действие, формирование, иго, район, восток, провинция, хасека, ополчение, интерес, коалиция, союзник, дамаск, ополчение, связь, корпус, стража, революция, момент, войско, наступление, манбидж, курд, юго-восток, сирия, пентагон, новое, сила, регион, пора, формирование, чёрный, халифат, штат, конец, конец, военный, действие, район, удар, ...]
# 22                                                                                                                                                                        [взгляд, событие, человек, точка, полюс, лёд, глубина, километр, май, год, новозеландец, эдмунд, хиллари, шерп, тенциг, норгейм, гора, мир, эверест, мини-подлодка, мир, глубина, минута, выход, полынь, условие, компас, полюс, человек, имя, артур, чилингаров, анатолий, сагале, владимир, груздев, евгений, черняев, аппарат, высота, имя, хиллари, норгейм, гордость, институт, спуск, миро, значение, страна, исследование, арктика, точка, зрение, наука, погружение, хребет, котловина, амундсена, дно, хребет, проблема, делимитация, граница, время, доля, бумага, ленин, 26-метр, год, декрет, цик, граница, ссср, полюс, линия, долгота, середина, пролив, восток, точка, граница, запад, треугольник, лада, территория, океан, размер, тысяча, километр, заявление, время, лёд, обстановка, мир, год, переговоры, положение, конвенция, оон, право, ...]
# 23                                                                                                                                                    [март, центр, фонд, мир, метр, метр, поэт, геннадий, калашников, книга, центр, циклон, центр, ворот, покровка, страница, метр, пруд, вечер, память, анри, лариса, волохонский-пивир, париж, александр, др, очерк, прота, михаил, аксёнов-меерсон, альманах, дар, доме-музей, марина, цветаев, борисоглебский, страница, метр, рамка, проект, среда, стих, художница, ирина, затуловскай, март, пятница, пироговка, дом, москва, метр, пироговский, этаж, зал, эшборн, метр, обсуждение, рукопись, антология, верлибр, перевод, екатерина, любомиров, елена, зейферт, вячеслав, куприянов, владимир, пряхин, василий, бородин, илья, семененко-басин, георгий, геннис, мария, попов, др, библиотека, центр, лихачев, метр, поэт, вадим, банник, библиотека, трифонов, метр, заседание, клуб, взгляд, владимир, пряхин, тема, комбинаторика, стиль, целостность, мысль, ян, выговский, ...]
# 24      [неделя, ространснадзор, обеспокоенность, деятельность, авиакомпания-лоукостер, работа, авиакомпания, заявление, итог, проверка, авиакомпания, победа, связь, обращение, депутат, госдума, ведомство, пресс-релиз, неправда, лоукостёр, гражданин, возможность, перелёт, цена, госдума, законодательство, ряд, изменение, избранник, орган, надзор, сфера, транспорт, образ, ространснадзор, общественность, заблуждение, вопрос, уровень, президент, владимир, путин, создание, лоукостер, важность, обеспечение, мобильность, население, доступность, авиаперелёт, суть, роль, лоукостер, система, страна, интерес, ведомство, интерес, пассажир, ограничение, вес, багаж, большинство, авиакомпания, победа, правило, авиакомпания, багаж, килограмм, ограничение, мера, салон, самолёт, полёт, авиакомпания-лоукостер, место, самолёт, авиакомпания, премиум, класс, салон, люба, душа, багаж, пассажир, уровень, сервис, багаж, место, место, опыт, цель, лоукостер, люба, багаж, ограничение, пассажир, авиакомпания, провоз, ...
# 25                                                                             [неделя, развитие, история, интервью, алексей, серебряков, журналист, юрий, дудь, актёр, число, километр, москва, элемент, 1990-ха, год, пора, знание, сообразительность, предприимчивость, достоинство, идея, идея, сила, наглость, хамство, заявление, интернет-пользователь, коллега, серебряков, пример, режиссёр, владимир, андрей, возмущение, серебряков, канада, россия, родина, день, депутат, госдума, партия, лдпр, иван, сухарев, фильм, госфинансирование, актёр, взгляд, запрос, имя, министр, культура, пожелание, список, запрет, рекомендация, режиссёр, внимание, ситуация, действие, депутат, недовольство, защитник, идея, зампредседатель, комитет, госдума, культура, елена, предложение, сухарев, идея, член, совет, минкультуры, россия, павел, пожигайло, бред, пожигайло, очередь, серебряков, человек, внимание, актёр, ребёнок, грязь, традиция, донос, точка, зрение, человек, право, позиция, риа, новость, слово, пожигайло, ...]
# 26                                                                                             [источник, тепло, земля, планета, отличие, энергия, энергия, ветер, источник, энергия, погода, преимущество, развитие, энергетика, рост, температура, глубина, среднее, температура, глубина, градус, цельсий, метр, оценка, ресурс, территория, россия, пересчёт, тонна, топливо, запас, топливо, количество, энергия, земля, солнце, часть, атмосфера, величина, поток, тепло, поверхность, земля, континент, поток, тепло, недра, земля, часть, поток, энергия, атмосфера, пространство, часть, глубина, метр, теплов, поток, единица, площадь, поверхность, произведение, градиент, температура, среда, часть, океан, коэффициент, теплопроводность, образец, порода, условие, залегание, пол, земля, протекание, процесс, недра, распределение, поток, область, корреляция, структура, континент, значение, поток, щит, теплов, поток, регион, область, вулкан, вариация, поток, среднее, значение, среднее, крыло, котловина, теплов, ...]
# 27                                                                                                                     [алексей, время, выбор, сила, ксения, собчак, собчак, кандидат, схема, власть, дело, время, соратник, основатель, фонд, борьба, коррупция, арест, оппозиционер, выборы, власть, вопрос, собчак, правило, электорат, дом, повышение, процент, голос, владимир, путин, оппозиция, цикл, главное, вопрос, поляризация, система, фигура, позиция, система, подпись, депутат, россия, люба, компромисс, фигура, власть, год, процесс, радикализация, риторика, оппозиция, действие, система, время, власть, собчак, сотрудничество, электорат, задача, система, круг, время, собчак, фигура, круг, избиратель, антирейтинг, электорат, путин, схема, интерпретация, план, власть, собчак, игра, интерес, очередь, интерес, часть, общество, задача, либерал, система, создание, партия, перспектива, попытка, михаил, прохоров, структура, путь, собчак, дмитрий, гудков, интерес, власть, создание, партия, разделение, ...]
# 28                                                                                                                    [саванна, мерка, город, километр, си-айленд, день, военный, городок, тысяча, журналист, член, делегация, саммит, восьмёрка, тысяча, военный, полицейский, итог, житель, саванна, человек, форма, саванец, улица, человек, камуфляж, угол, нашествие, антиглобалист, история, саванна, интервенция, война, генерал, уильям, шерман, армия, южанин, город, растерзание, солдат, предание, красота, место, нрав, горожанин, саванна, месяц, курорт, город, страх, надежда, пришелец, антиглобалист, борец, капитализм, место, отель, мотель, радиус, миля, магазин, день, служба, церковь, синагога, город, дружина, защита, улица, вандал, пресс, энтузиазм, гость, ряд, повестка, мероприятие, серьёз, программа, митинг, шествие, концерт, борец, планет, свобода, слово, справедливость, братия, большинство, остров, саммит, хроника, монитор, пресс-центр, пресса, акция, отдушина, перо, событие, разочарование, ...]
# 29                                                                                                [пушкин, состояние, душа, германн, ум, глаз, сальери, первое, монолог, безумие, способность, увлечение, идея, следование, цель, вершина, искусство, случай, гармония, жизнь, шутка, германн, сальери, злодейство, гений, соперник, сальери, жанр, воин-захватчик, моцарт, сальери, зависть, вид, собственность, поклонение, сальери, детство, музыка, правда, земля, правда, гений, жалоба, дар, любим, искусство, лягушка, труп, слово, музыка, чад, прах, желание, преступление, следствие, суд, слово, подозрение, отклонение, обоснование, убийство, искусство, моцарт, экспертиза, вменяемость, логика, бокал, отрава, чаша, дружба, бог, музыка, враг, оправдание, убийство, бесполезность, жертва, время, пушкин, пси-наука, предмет, внимание, церковь, литература, современник, пушкин, игумен, игнатий, брянчанин, фарисей, бог, земля, спаситель, благосостояние, вымысел, прикрытие, справедливость, кровь, жертва, зависть, ...]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 1957                                                                                                                 [год, сила, соглашение, ес, турция, анкара, максимум, усилие, поток, беженец, путь, европа, брюссель, общественность, сделка, успех, действительность, эксперт, цель, соответствие, соглашение, обмен, мигрант, сирия, территория, ес, евросоюз, турция, беженец, пропорция, статистика, еврокомиссия, год, ес, территория, турция, тысяча, мигрант, тысяча, ход, визит, италия, ватикан, февраль, президент, турция, реджеп, тайип, ес, обещание, выплата, анкара, миллиард, евро, урегулирование, кризис, ес, содержание, беженец, миллиард, евро, пора, миллион, евро, деньга, бюджет, полумесяц, организация, ес, анкара, мигрант, территория, брюссель, сумма, объём, обязательство, речь, финансирование, лагерь, беженец, страна, восток, очередь, сирия, территория, турция, роль, род, фильтр, евросоюз, переселенец, договорённость, сторона, друг, друг, несоблюдение, условие, брюссель, турция, должное, ...]
# 1958                                                       [миллиардер, илона, маск, очередь, основатель, компания, фирма, время, сша, огнемёт, помпа, агентство, би-би-си, объявление, начало, приём, предзаказ, огнемёт, маск, пост, ссылка, сайт, компания, предприниматель, устройство, вечеринка, случай, зомби-апокалипсис, зомби-апокалипсис, огнемёт, толпа, живой, мертвец, деньга, маск, ответ, опасение, подписчик, законность, приобретение, хранение, огнемёт, миллиардер, законодательство, устройство, условие, длина, пламя, метр, нож, страх, сайт, огнемёт, желающий, доллар, штука, описание, поставка, страница, компания, огнетушитель, стоимость, доллар, штука, читатель, маск, декабрь, огнемёт, случай, тысяча, кепка, логотип, задача, компания, строительство, тоннель, балтимор, вашингтон, нью-йорк, филадельфия, количество, кепка, пользователь, интернет, сайт, фирма, пароль, страница, изображение, огнемёт, дизайн, вопрос, читатель, американец, дизайн, винтовка, огнемёт, сша, популярность, оружие, ...]
# 1959                                                                                                                                  [спортсмен, игра, пхенчхан, флаг, гимн, виталий, кома, олимпиада, кома, орган, тестирование, создание, комитет, россия, расход, комитет, ход, расследование, сумма, миллион, доллар, цена, участие, олимпиада, движение, мнение, россия, олимпиада, депутат, сенатор, судьба, лыжа, конёк, прыжок, год, главное, соревнование, жизнь, мнение, владимир, путин, октябрь, инстанция, выступление, олимпиец, флаг, глава, александр, жуков, россиянин, флаг, игра, страна, спортсмен, пхенчхан, сборная, россия, атлет, россия, жуков, декабрь, журналист, формулировка, название, страна, победа, извинение, нарушение, правило, страна, тон, содержание, выступление, глава, верх, виктор, чемпион, шорт-трек, пхенчхан, флаг, россия, игра, сочи, сборная, россия, сборная, корея, награда, флаг, игра, год, олимпиада, соревнование, личность, страна, форма, принцип, президент, майкл, килланина, ...]
# 1960                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [соискание, премия, текст, жанр, стих, проза, эссе, язык, рукопись, текст, формат, сми, январь, год, премия, номинация, нонконформизм-судьба, совокупность, заслуга, нонконформизм-поступок, текст, год, лауреат, премия, номинация, награда, размер, приём, работа, январь, год, апрель, год, работа, формат, адрес]
# 1961                                                                                                                              [импорт, вооружение, условие, санкция, страна-покупатель, риска, союзник, сша, ближний, среднее, восток, чаща, выбор, польза, техника, египет, сборка, танк, парк, попытка, перехват, ракета, интерес, конец, февраль, ирак, намерение, комплекс, аравия, стадия, сделка, поставка, система, информация, ресурс, египет, конец, год, сборка, танк, машинокомплект, уралвагонзавод, египет, год, танк, вид, штука, данные, год, россия, начало, том-90с/ск, ирак, бронетехника, вьетнам, военный, эксперт, субха, назим, агентство, мысль, союзник, вашингтон, мир, чаща, выбор, польза, вооружение, мнение, субха, назим, страна, покупка, система, союзник, вашингтон, регион, правило, оружие, выбор, польза, система, основное, причина, развёртывание, система, сирия, конкурент, вооружение, отличие, оружие, защита, союзник, регион, сохранение, будущее, союзник, режим, дальность, обнаружение, ...]
# 1962                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [поручение, президент, ресурс, закупка, препарат, помощь, миллиард, рубль, министр, здравоохранение, рф, вероника, миллиард, препарат, аппарат, вентиляция, лёгкое, число, применение, дом, слово, министр, регион, момент, проблема, поставка, препарат, угроза, минздрав, запас, мера, неделя]
# 1963                                                                                                       [день, президент, федерация, андрей, филат, президент, холдинг, ратм, ассоциация, материал, эдуард, таран, договор, партнерство, соглашение, финансирование, холдинг, программа, развитие, шахматы, сочи, центр, сириус, центр, работа, май, год, руководство, 14-го, чемпион, мир, владимир, крамник, старт, начинание, президент, россия, владимир, путин, церемония, открытие, сириус, соглашение, план, привлечение, занятие, шахматист, тренер, россия, год, сессия, работа, наставник, холдинг, партнёр, федерация, шахматы, область, клуб, сибирь, счёт, ратм, частность, проведение, новосибирск, октябрь, прошлое, год, суперфинал, чемпионат, россия, мужчина, женщина, команда, сибирь, шахматист, владимир, крамник, левон, аронянин, год, чемпионат, страна, кубок, европа, холдинг, шахматы, род, отдача, вложение, бизнес, целое, шахматы, футбол, хоккей, марин, макарычев, комментарий, руководитель, холдинг, ...]
# 1964                [апрель, президент, рф, стратегия, безопасность, федерация, период, год, документ, направленность, россия, вступление, сила, соглашение, конвенция, оон, изменение, климат, россия, соглашение, стратегия, угол, вектор, политика, вопрос, пара, слово, стратегия, стратегия, безопасность, документ, основа, формирование, реализация, политика, сфера, обеспечение, безопасность, уровень, цель, политика, предотвращение, ликвидация, вызов, угроза, безопасность, безопасность, часть, нацбезопасность, стратегия, смена, стратегия, рф, охрана, среда, обеспечение, развитие, год, указ, президент, апрель, отличие, стратегия, основа, взаимодействие, орган, власть, страна, субъект, орган, самоуправление, предприниматель, объединение, обеспечение, решение, проблема, развитие, экономика, улучшение, состояние, среда, цель, реализация, право, гражданин, среда, право, поколение, пользование, потенциал, поддержание, развитие, решение, задача, связь, осуществление, мера, защита, улучшение, среда, ...]
# 1965                                         [юг, россия, проект, эколог, неприятие, строительство, автотрасса, черкесск–адлер, канал, каспий–аз, евразия, ряд, объект, проведение, олимпиада, год, сочи, эколог, реализация, проект, ущерб, природа, катастрофа, пятница, совет, администрация, край, план, строительство, акватория, сочи, остров, федерация, возведение, район, остров, площадь, гектар, баланс, курорт, перемещение, масса, земля, загрязнение, море, проект, реализация, год, степень, борец, охрана, природа, план, стройка, частность, союз, первое, вице-премьер, дмитрия, медведев, обращение, связь, поддержка, проект, строительство, автотрасса, черкесск–адлер, канал, каспий–аз, евразия, мнение, эколог, реализация, проект, уничтожение, комплекс, округа, значение, юг, россия, проект, дмитрий, медведев, прошедшее, конец, январь, форум, промышленник, предприниматель, краснодар, ход, день, пресс-конференция, волгоград, автодорога, руководство, карачаево-черкесия, территория, заповедник, ядро, ...]
# 1966                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [музыка, век, время, царствование, династия, стюарт, филармония, исполнение, анна, тончева, дульцимер, лютня, арфа, свирель, андрей, байрамов, боуран, владимир, лазерсон, волынка, илья, мовчан, скрипка, анатолий, гринденко, виола, гамб, манускрипт, балкар, произведение, тобиас, хьюма, джеймс, освальд, программа, рил, жига, хорнпайп]
# 1967                                                                                                                                                                                        [автодром, братислава, гонка, этап, чемпионат, мир, автогонки, класс, туринг, заезд, калитка, разница, гонка, успех, гонка, россия, ступенька, подиум, пилот, хонда, шанс, квалификация, знак, борьба, пилот, позиция, старт, лада, попадание, квалификация, автомобиль, гонка, борьба, подиум, пилот, хонда, день, гонка, пилот, целое, право, хонда, ладь, позиция, хафф, труд, видимость, позиция, катсбург, позиция, конец, конец, управление, ощущение, машина, лопес, порядок, порядок, пилот, интервью, гонка, ход, гонка, машина, скольжение, попытка, иван, мюллер, момент, лопёс, ситройня, роба, хаффа, время, атака, половина, пелетон, борьба, позиция, итог, 16-го, место, обгон, сход, соперник, гонка, момент, скорость, квалификация, габриэле, тарквини, хонда, десятка, старт, позиция, лада, прошествие, круг, бокс, рука, ...]
# 1968                                                                                                                           [север, юг, картина, мир, гонконг, представление, расположение, полюс, экономика, соглашение, колония, полуостров, остров, гонконг, остров, большинство, июль, год, состав, кнр, статус, регион, сара, гонконг, китай, формула, страна, система, сохранение, принцип, организация, экономика, самоуправление, сфера, жизнь, исключение, оборона, политика, ряд, аспект, режим, чудо, политика, основа, год, правление, гонконг, регион, планета, сара, 7-е, место, мир, доход, население, тысяча, доллар, швейцария, великобритания, франция, германия, канада, нидерланды, австрия, сравнение, россия, показатель, раз, тысяча, доллар, ресурс, гонконг, место, иждивенец, труд, успех, часть, население, плата, тысяча, доллар, доллар, переход, гонконг, великобритания, состав, кнр, упадок, колония, освобождение, сфера, услуга, специализация, экономика, сара, житель, гонконг, сектор, ввп, сфера, ...]
# 1969                                                                                          [россия, количество, человек, статус, беженец, получатель, убежище, год, раз, эксперт, основное, гражданин, украина, власть, помощь, образ, родина, рф, украина, большинство, условие, гастарбайтер, данные, росстат, прошлое, год, статус, тысяча, человек, 2016-метр, тысяча, заявитель, гражданин, украина, россия, конфликт, юго-восток, страна, правозащитник, снижение, число, человек, рф, документ, отказ, власть, украинец, пора, версия, статус, беженец, год, месяц, окончание, человек, заявление, продление, случай, основание, получение, родина, жизнь, здоровье, человек, зампред, комитет, помощь, беженец, содействие, елена, буртина, власть, повод, нормализация, ситуация, юго-восток, украина, стрельба, человек, время, время, разруха, слово, буртина, институт, россия, статья, закон, беженец, определение, пример, человек, соображение, гуманизм, россия, чиновник, понятие, усмотрение, почва, злоупотребление, ...]
# 1970    [медик, автор, стратегия, развитие, здравоохранение, столица, год, группа, главврач, больница, поликлиника, проект, документ, обсуждение, медработник, представитель, сообщество, представитель, отрасль, москва, разработка, документ, здравоохранение, год, главное, врач, клиника, мэр, сергей, собянин, подведение, итог, трансформирование, отрасль, год, градоначальник, система, здравоохранение, уровень, сообщество, пациент, москвич, множество, обращение, вопрос, будущее, здравоохранение, вопрос, собянин, задача, президент, продолжительность, жизнь, год, москва, задача, задача, год, мэр, важность, участие, сообщество, создание, стратегия, простой, способ, дело, чиновник, эксперт, бумага, градоначальник, сайт, работа, кома, жизнь, медик, разработка, стратегия, основа, пациентоориентированность, этап, элемент, идеология, год, медучреждение, поликлиника, пребывание, пациент, запись, специалист, зарплата, работник, обязанность, курс, удовлетворение, интерес, пациент, введение, москва, сервис...
# 1971                                                                                                                                        [леди, бёрдо, грета, гервиг, прокатчик, название, птица, птаха, победа, номинация, оскар, приз, картина, итог, золото, глобус, награда, присутствие, номинация, случай, женщина-режиссёр, кино, киноакадемия, практика, случай, леди, бёрдо, роль, вайнштейн-гейт, право, женщина, число, право, режиссёр, действие, ретрокартина, год, сакраменто, героиня, ученица, школа, кристина, сирша, ронана, нью-йорк, повод, родитель, лори, меткаф, трейся, леттс, леди, бёрдо, фон, репетиция, спектакль, концерт, разговор, терроризм, парковка, любовь, секс, мальчик, исполнение, герой, год, актёр, тимоти, шалам, особа, драма, взросление, обстоятельство, вид, семья, городок, амбиция, грета, гервиг, качество, соавтор, актриса, муза, режиссёр, баумбах, год, лицо, кинематограф, молодая, американка, бездействие, апатия, дебют, вопрос, время, фильм, участие, гервиг, роль, актриса, ...]
# 1972                                                                                                                                                         [событие, март, молодёжь, поколение, конфликт, ребёнок, школот, молодёжь, власть, уровень, лексика, высказывание, время, измерение, образ, курица, утёнок, кудахтанье, берег, вода, власть, диалог, молодёжь, диалог, мысль, власть, молодёжь, человек, молодая, горожанин, рубеж, век, дата, уход, отставка, информация, молодёжь, рояль, минимум, год, чемодан, строка, диалог, телеграмма, писатель, прилепин, молодая, аудитория, вопрос, автограф, молодёжь, ребёнок, год, принцип, уста, человек, мнение, степь, украина, моторола, джип, америка, сталин, отношение, пустословие, жизнь, план, ценность, илоно, маск, встреча, тысяча, вопрос, мир, маска, мир, прилепин, география, картина, мир, способ, век, этаж, пирамида, маслоу, вопрос, подросток, запрет, сеть, милон, ребёнок, фёдор, бондарчук, кино, удивление, нло, чертаново, москва, взрослый, человек, ...]
# 1973                                                                                                                                                                                              [сборник, стих, рассказ, книжка, стих, рассказ, сборник, стих, рассказ, автор, ян, шенкман, поэт, журналист, книга, голубь, ктой, книга, учёт, жизнь, др, ян, газета, журнал, место, поэт, журналистика, стих, страница, обложка, отзыв, шенкмане, евгений, буним, андрей, родионов, стих, буним, фиксация, тишина, одиночество, холод, поэзия, рёв, усмешка, постмодерн, мысль, буним, андрей, родионов, фиксация, тишина, мама, мама, год, прошлое, свидетельство, рождение, тишина, камень, объятие, ян, тишина, холод, ребёнок, деньга, утро, берег, бог, ответ, мороз, кожа, шенкман, реальность, читатель, шенкман, реальность, название, книга, парадокс, анекдот, время, галлюцинация, род, эрекция, революция, усталость, год, год, анекдот, ян, стих, желание, стих, поэт, похвала, впечатление, шенкман, тишина, одиночество, ...]
# 1974                                                                                                                      [республика, имидж, лидер, движение, энергетика, швейцария, источник, энергия, технология, лидер, разработка, применение, направление, энергетика, республика, школа, лозанна, институт, страна, вуз, мир, школа, специалист, область, наука, информатика, центр, школа, лозанна, доктор, франсуа, координация, взаимодействие, подразделение, тема, энергия, энергетика, число, лаборатория, территория, парк, институт, предприятие, сотрудник, фирма, прошлое, год, миллион, франк, капитал, россия, финасирование, раз, результат, год, энергетика, франсуа, разработка, речь, самолёт, энергия, ход, полёт, система, энергия, течение, день, размах, крыло, метр, вес, том, крыло, тысяча, элемент, энергия, электромотор, мощность, сила, бертран, пиккар, инженер, андрэ, боршберг, самолёт, публика, конец, июнь, год, город, пайерна, полёт, новое, самолёт, длина, метр, размах, крыло, метр, площадь, ...]
# 1975                                                             [министр, юстиция, грузия, тея, цулукиани, экс-глава, мид, саломэ, зурабишвили, качество, кандидат, президент, мечта, выбор, октябрь, год, праймериза, эксперт, решение, движение, среда, часть, призыв, экс-президент, михаил, саакашвили, объединение, информация, цулукиани, зурабишвили, качество, участник, выбор, слив, министр, юстиция, страна, министр, дело, рейтинг, президент, грузия, конституция, полномочие, право, задействование, поправка, закон, инаугурация, октябрь, тея, цулукиани, саломэ, зурабишвили, плюс, пост, министр, юстиция, умение, позиция, ситуация, зависимость, обстоятельство, министр, дело, харизма, связь, арен, зурабишвили, структура, мид, франция, оон, актив, переговоры, мид, рф, вопрос, вывод, военный, база, территория, грузия, женщина, заявление, политик, представитель, общественность, корень, эпоха, царица, тамара, грузинка, средневековье, представитель, большинство, заза, габуния, выбор, женщина-политик, ...]
# 1976                                  [соотечественник, илья, мечник, премия, область, физиология, медицина, год, открытие, макрофаг, клетка-пожиратель, патоген, процесс, фагоцитоз, половина, премия, немец, пауль, эрлихо, тело, антитело, десятилетие, иммунолог, связь, фагоцитоз, выработка, антитело, лейкоцит, человек, протеин-«антиген, иммунитет, вид, реакция, отторжение, аббревиатура, антиген, человек, океан, антиген, комплекс, гистосовместимость, макрофаг, клетка, толерантность, нарушение, расстройство, аллергия, диабет, склероз, биолог, белка, сенсор, антиген, журнал, обложка, изображение, комплекс, помощь, микроскоп, создание, прибор, премия, год, комплекс, мембрана, статья, обложка, процесс, формирование, пептид, клетка, помощь, образ, расшифровка, смысл, открытие, год, время, раскрытие, природа, процесс, речь, работа, гидрогеназа, водород, работа, основа, экономика, железо, таблица, менделеев, марганец, металл, валентность, электрон, железо, гемоглобин, гидрогеназа, железо, состав, ...]
# 1977                                                                                                                                          [год, год, день, рождение, иван, тургенев, год, момент, знакомство, писатель, полина, виардо, поэт, звезда, сцена, год, жизнь, петербург, концерт, знакомство, ритуал, молодая, аристократ, богач, поклонник, искусство, восхищение, артистка, выступление, визит, роман, дружба, тургенев, виардо, год, книга, историк, писатель, барбие, взаимоотношения, писатель-дворянин, певица, корень, биография, полина, виардо, материал, блеск, барбие, роман, нюанс, замечание, контекст, деталь, быт, подробность, чувство, такт, мера, работа, книга, виардо, россия, родина, певица, жизнеописание, барбие, эволюция, талант, судьба, полина, гарсиа, замужество, виардо, дочь, певец-испанец, семья, франция, семья, полина, звук, ария, аккорд, семья, культ, трудолюбие, нелёгкая, труд, специальность, конец, 1830-ха, полина, звезда, сцена, начало, европа, муж, служба, театр, работа, ...]
# 1978                                                                                     [госминистр, грузия, вопрос, реинтеграция, темур, якобашвили, суббота, эфир, телеканал, грузия, розыск, интерпол, бизнесмен, абхазия, лидер, сергей, багапш, россия, ответ, розыск, бизнесмен, кризис, отсутствие, москва, стратегия, поведение, отношение, республика, конец, неделя, москва, предел, забота, республика, гражданин, спецпредставитель, мид, рф, вопрос, отношение, страна, снг, валерий, кеняйкина, случай, тбилиси, операция, абхазия, осетия, россия, военный, метод, защита, соотечественник, образ, пора, москва, намёк, тбилиси, манёвр, армия, тоннель, образ, концентрация, спецназ, граница, осетия, точка, кеняйкина, россия, военный, конфликт, мид, рф, неделя, грузия, абхазия, сосредоточение, передислокация, боев, подразделение, ряд, соединение, армия, состояние, боев, готовность, выступление, тбилиси, угроза, сторона, россия, заявление, мид, апрель, сторона, обеспечение, агрессия, грузия, заявление, ...]
# 1979                                                                                                                              [китай, сезон, работа, собрание, представитель, орган, совет, момент, принятие, поправка, конституция, роль, партия, ограничение, срок, пребывание, председатель, кнр, власть, си, цзиньпин, пост, президент, сша, дональд, трамп, сообщение, сторонник, си, председатель, конец, жизнь, слово, трамп, пример, америка, конгрессмен, глава, государство, шутка, ряд, эксперт, запад, власть, си, шутка, газета, партия, источник, изменение, конституция, председатель, возможность, конец, день, сянвэй, комментатор, гонконг, си, подъём, экономика, система, управление, социализм, особенность, момент, демократия, автократия, месседж, си, партия, контроль, сторона, жизнь, общество, стремление, народ, жизнь, мечта, мечта, жизнь, полномочие, рука, кормчий, основатель, кнр, мао, цзэдун, параллель, мао, эксперимент, скачок, революция, хаос, голод, десятка, миллион, жертва, смерть, мао, ...]
# 1980    [манеж, неделя, посольство, швейцария, представитель, бизнес, эксперт, журналист, обсуждение, инновация, отрасль, энергоэффективность, проблема, внедрение, технология, мероприятие, октябрь, год, тема, сотрудничество, страна, возможность, применение, решение, россия, работа, рынок, специфика, вице-президент, михаил, аким, оценка, дисбаланс, мощность, эксплуатация, объект, генерация, возраст, год, перспектива, предпосылка, строительство, мощность, спрос, время, модернизация, повышение, производительность, михаил, аким, обновление, драйвер, рост, энергетика, внедрение, перестройка, сеть, модель, введение, количество, объект, генерация, эксперт, главное, направление, развитие, повышение, эффективность, сеть, число, счёт, внедрение, автоматизация, день, множество, решение, энергетика, переход, обеспечение, кибербезопасность, продвижение, источник, энергия, россия, опыт, страна, евросоюз, направление, интерес, вопрос, утилизация, отход, процесс, пара, сжигание, производство, электроэнерг...
# 1981                                                                           [музей, искусство, угол, произведение, коллекция, тысяча, работа, серия, выставка, 2009-метр, подход, спецпроект, куратор, людмила, андреев, анна, арутюнян, андрей, егоров, подход, план, исток, художник, произведение, художник, арт-дуэт, анфилада, зал, выставка, зал, борис, анисфельд, василий, шухаев, нико, николай, андрон, франциско, инфанте-аран, нонна, горюнов, эдуард, штейнберг, борис, орлов, айдан, салахов, виталий, ирина, группа, провмыза, галина, мызникова, сергей, провор, константин, звездочёт, коридор, авангардист, давид, бурлюк, вячеслав, колейчук, документация, перформанс, художник, поколение, андрей, кузькин, документация, снимка, подпись, планшет, произведение, серия, право, жизнь, воспоминание, человек, чемодан, надпись, чемодан, место, фотокарточка, вещь, право, жизнь, пространство, анфилада, особняк, серия, эпиграф, послесловие, выставка, лейтмотив, целое, жанр, перформанс, документация, жизнь, ...]
# 1982                                                                                                                           [парламент, украина, власть, страна, претензия, рф, агрессия, кабинет, министр, страна, методика, определение, ущерб, объём, убыток, украина, сторона, рф, постановление, депутат, парламент, депутат, правительство, методика, определение, ущерб, объём, убыток, украина, результат, агрессия, рф, претензия, россия, основное, страна, балтия, оккупация, пример, год, время, президент, литва, валдас, адамкус, убыток, республика, состав, ссср, миллиард, доллар, сейм, республика, год, правый, депутат, парламент, литва, россия, миллиард, доллар, избранник, счёт, расход, консервация, игналинский, аэс, период, эксплуатация, требование, брюссель, конец, год, латвия, сентябрь, год, глава, комиссия, подсчёт, ущерб, оккупация, рута, паздёр, республика, год, бытование, состав, ссср, миллиард, евро, власть, эстония, фон, филантроп, вывод, эстония, руководство, москва, ущерб, размер, ...]
# 1983                                                                                                                [февраль, классик, чернила, годовщина, год, день, смерть, пушкин, тема, гибель, александр, сергей, дуэль, история, человечество, убийство, человек, рукопись, истина, дело, пример, гоголь, второе, том, мёртвый, душа, михаил, булгаков, редакция, мастер, маргарита, рука, печка, черновик, роман, дьявол, редактор, борис, пастернак, огонь, рукопись, пьеса, свет, заказ, мхат, анна, ахматов, произведение, несовершенство, боязнь, обыск, достоевский, поэт, прозаик, олег, лапшин, рукопись, доктор, наука, специалист, физика, горение, взрыв, финалист, премия, нонконформизм, рукопись, мнение, книга, годовщина, событие, год, февраль, год, вторник, страна, праздник-карнавал, великое, пост, флоренция, костёр, тщеславие, церемония, сожжение, книга, инструмент, литература, искусство, предмет, зеркало, карта, флорентиец, подача, монах, реформатор, джироламо, савонарола, борец, очищение, народ, ...]
# 1984                                                                                         [фон, потеря, ирак, власть, штат, расширение, угроза, регион, среднее, восток, дом, день, сша, психоз, появление, атака, аль-каида, объект, атака, персонал, аравия, ночь, воскресение, сша, минимум, пересмотр, тактика, регион, данные, агентство, человек, результат, взрыв, квартал, эр-рияд, основное, представитель, страна, египтянин, сириец, ливанец, суданец, иорданец, палестинец, данные, власть, пострадавший, гражданин, индия, франция, германия, италия, споуксмена, посольство, королевство, гражданин, сша, гражданин, данные, мид, власть, теракт, организация, аль-каида, власть, эр-рияда, вашингтон, журналист, наблюдатель, параллель, теракт, столица, май, человек, американец, сомнение, метод, материал, аль-каида, май, рейтер, слово, представитель, правительство, речь, человек, район, теракт, десятка, военный, нью-йорк, таймс, место, город, закон, королевство, дипквартал, террорист, сотрудник, служба, ...]
# 1985                                                                                               [время, духовенство, решение, государь, война, патриарх, русь, кирилл, президент, румена, радева, премьер-министр, борисов, время, встреча, софия, март, глава, рпц, болгария, визит, участие, торжество, повод, 140-летие, освобождение, болгария, иго, особа, роль, церковь, принятие, император, александр, решение, кампания, история, война, год, страна, участие, воин, союз, республика, военный, блок, военный, операция, правительство, поддержка, сторона, народ, связь, акция, патриарх, кирилл, премьер-министр, борисов, вопрос, освобождение, болгария, усилие, сторона, государство, церковь, начало, кампания, храм, молебен, освобождение, брат, посыл, народ, церковь, мнение, глава, рпц, единодушие, царь, народ, чувство, поездка, патриарх, интервью, сми, мысль, роль, церковь, мобилизация, общество, война, одухотворённость, идея, солидарность, жертва, солдат, правительство, поддержка, поддержка, жертва, ...]
# 1986                                                                                                                                                    [март, год, день, рождение, мариуса, петипа, хореограф, танцовщик, педагог, склон, день, перо, мемуары, число, эпизод, биография, мастер, книга, эпоха, дар, петипа, балет, слава, совершенство, писательница, историк, юлий, яковлев, балет, середина, начало, век, книга, биография, хореограф, спектакль, попытка, мариус, петипа, зритель, время, публика, контакт, зритель, балет, книга, яковлев, слог, роман, великое, множество, факт, вопрос, петипа, музыка, балет, минкуса, хореограф, соавтор, композитор, жанр, 1890-е, год, балет-феерия, исследовательница, исток, балет, почва, век, год, царствование, императрица, анна, иоанн, кадет, корпус, санкт-петербург, менуэт, руководство, хореограф, жан-батист, ланда, год, балет, россия, труппа, основное, ребёнок, прислуга, россия, пора, школа, свод, правило, энергия, прыжок, поступь, прыжок, линия, пируэт, ...]
# Name: content_norm, Length: 1987, dtype: object

# %%
mystemmer = Mystem(grammar_info=True, disambiguation=False, entire_input=True) #если оставить дизамбигуацию,
#это будет опять же долго
def normalize_with_mystem(text):
    words = [word.strip(punct) for word in text.lower().split()]
    new_text = ' '.join(words)
    analysis = mystemmer.analyze(new_text)
    words = []
    for word in analysis:
        if word.get('analysis'):
            if 'S,' in word['analysis'][0]['gr'] and not 'имя' in word['analysis'][0]['gr']: #попробуем избавиться
                #от Дарьи но оставить Собянина
                words.append(word['analysis'][0]['lex'])
    return words

print(normalize_with_mystem(data['content'][0])) #стало лучше
# Out:
# ['яблоко', 'фракция', 'задача', 'яблоко', 'привлечение', 'человек', 'участие', 'выборы', 'деятельность', 'партия', 'яблоко', 'регион', 'руководство', 'деятельность', 'акция', 'уровень', 'борьба', 'призыв', 'профессия', 'обязанность', 'человек', 'жизнь', 'год', 'государство', 'долг', 'мнение', 'специалист', 'область', 'политика', 'арбатов', 'переход', 'армия', 'бюджет', 'уровень', 'яблоко', 'акция', 'освобождение', 'политзаключенный', 'вмешательство', 'россия', 'политика', 'украина', 'активист', 'петрунин', 'год', 'год', 'москва', 'семья', 'взгляд', 'детство', 'политика', 'власть', 'крым', 'война', 'украина', 'убийство', 'немцов', 'сторона', 'школа', 'сила', 'смена', 'власть', 'россия', 'новичков', 'влияние', 'преподаватель', 'обществознание', 'ситуация', 'страна', 'искренность', 'заинтересованность', 'вопрос', 'материал', 'сми', 'время', 'наблюдение', 'позиция', 'образ', 'команда', 'единомышленник', 'пример', 'ровесник', 'яблоко', 'яблоко', 'клуб', 'рамка', 'лекция', 'кинопоказ', 'тема', 'наступление', 'консерватизм', 'обсуждение', 'альтернатива', 'ситуация', 'экономика', 'участник', 'стол', 'мероприятие', 'место', 'дискуссия', 'участие', 'гость', 'яблоко', 'повестка', 'ноябрь', 'прошлое', 'год', 'карелия', 'акция', 'свобода', 'колония', 'процесс', 'правонарушение', 'активист', 'пора', 'ставрополец', 'акция', 'декриминализация', 'насилие', 'фотография', 'интернет', 'март', 'акция', 'праздник', 'день', 'борьба', 'право', 'женщина', 'россия', 'пародия', 'смысл', 'женщина', 'украшение', 'пол', 'отделение', 'деятельность', 'завод', 'электроцинк', 'ущерб', 'среда', 'мероприятие', 'кандидат', 'выборы', 'уровень', 'год', 'активист', 'кампания', 'страна', 'выборы', 'президент', 'яблоко', 'кандидат', 'основатель', 'партия', 'явлинский', 'последовательность', 'неготовность', 'принцип', 'процент', 'уважение', 'поддержка', 'проблема', 'форма', 'сайт', 'заявка', 'вступление', 'регион', 'отделение', 'яблоко', 'функция', 'организатор', 'ответственность', 'активист', 'задача', 'активист', 'работник', 'обязательство', 'срок', 'часть', 'план', 'условие', 'деятельность', 'черносотенец', 'движение', 'акция', 'силовик', 'дело', 'исключение', 'заведение', 'родитель', 'активист', 'репрессия', 'яблоко', 'активист', 'год', 'сотрудник', 'спецслужба', 'проблема', 'ребята', 'деятельность', 'прошлое', 'месяц', 'лидер', 'яблоко', 'наркотик', 'сизо', 'год', 'лишение', 'свобода', 'яблоко', 'усилие', 'освобождение', 'число', 'кампания', 'солидарность', 'лозунг', 'яблоко', 'акция', 'требование', 'убийца', 'яблочник', 'журналист', 'куашево', 'позиция', 'жизнь', 'адрес', 'раз', 'угроза', 'сторона', 'силовик', 'настоящее', 'время', 'дело', 'факт', 'убийство', 'репрессия', 'пропаганда', 'количество', 'человек', 'власть', 'политика', 'застой', 'апатия', 'год', 'всплеск', 'активность', 'жизнь', 'паблик', 'подросток', 'керенский', 'мартов', 'ельцин', 'март', 'молодежь', 'акция', 'запрос', 'справедливость', 'честность', 'открытость', 'политика', 'задача', 'яблоко', 'молодежь', 'власть', 'насилие', 'начало', 'цикл', 'перемена']

# %%
data['content_norm'] = data['content'].apply(normalize_with_mystem)

# %%
def try_tf_idf(data, threshold=None):
    data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(10)
    data['content_norm_str'] = data['content_norm'].apply(' '.join)
    tfidf = TfidfVectorizer(ngram_range=(1,2), min_df=5)
    tfidf.fit(data['content_norm_str'])
    id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}
    
    texts_vectors = tfidf.transform(data['content_norm_str'])
    if not threshold:
        keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-11:-1]] 
    else:
        keywords = [[id2word[w] for w in top if w>threshold] for top in texts_vectors.toarray().argsort()[:,:-31:-1]]
    return keywords, texts_vectors.toarray().argsort()[:,:-11:-1]

# %%
keywords = try_tf_idf(data)[0]
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.13
# Recall -  0.25
# F1 -  0.17
# Jaccard -  0.1

# %%
# приросло совсем немного.нужно что-то более умное чем другой пос теггер
# видно, что брать топ-10 это плохо. Может быть так, что релевантные топ-3. или топ-20. Лучше придумать какой-то порог
keywords, vectors = try_tf_idf(data, threshold=2000)
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.06
# Recall -  0.31
# F1 -  0.1
# Jaccard -  0.05

# %%
keywords, vectors = try_tf_idf(data, threshold=1000)
evaluate(data['keywords'], keywords)  # c приростом полноты получается, а вот с точностью все плохо
# Out:
# Precision -  0.06
# Recall -  0.32
# F1 -  0.1
# Jaccard -  0.05

# %% [markdown]
# ## Попробуем графы!

# %% [markdown]
# Большая часть методов для извлечения ключевых слов основана на применении графов. Основная идея - каким-то образом перевести текст в граф, а затем каким-то образом расчитать важность каждого узла и вывести топ-N самых важных узлов.
#
# Перевод текста в граф -  не тривиальная задача. Часто применяют такой подход - построим матрицу совстречаемости слов (в каком-то окне), эта матрица будет нашей матрицей смежности.

# %% [markdown]
# Для выбора важных узлов часто используют простой randow walk. Алгоритм примерно такой:
# 1) Каким-то образом выбирается первый узел графа (например, случайно из равномерного распределения)
# 2) на основе связей этого узла с другими, выбирается следующий узел
# 3) шаг два повторяется некоторое количество раз (например, тысячу) __*чтобы не зацикливаться, с какой-то вероятностью мы случайно перескакиваем на другой узел (даже если он никак не связан с текущим, как в шаге 1)__
# 5) на каждом шаге мы сохраняем узел в котором находимся
# 6) в конце мы считаем в каких узлах мы были чаще всего и выводим top-N
#
#
# Предполагается, что мы часто будем приходить в важные узлы графа.

# %%
from itertools import combinations

# %% [markdown]
# Для наглядности реализуем этот подход без networkx.

# %%
def get_kws(text, top=5, window_size=5, random_p=0.1):

    vocab = set(text)
    word2id = {w:i for i, w in enumerate(vocab)}
    id2word = {i:w for i, w in enumerate(vocab)}
    # преобразуем слова в индексы для удобства
    ids = [word2id[word] for word in text]

    # создадим матрицу совстречаемости
    m = np.zeros((len(vocab), len(vocab)))

    # пройдемся окном по всему тексту
    for i in range(0, len(ids), window_size):
        window = ids[i:i+window_size]
        # добавим единичку всем парам слов в этом окне
        for j, k in combinations(window, 2):
            # чтобы граф был ненаправленный 
            m[j][k] += 1
            m[k][j] += 1
    
    # нормализуем строки, чтобы получилась вероятность перехода
    for i in range(m.shape[0]):
        m[i] /= np.sum(m[i])
    
    # случайно выберем первое слова, а затем будет выбирать на основе полученых распределений
    # сделаем так 5 раз и добавим каждое слово в счетчик
    # чтобы не забиться в одном круге, иногда будет перескакивать на случайное слово
    
    c = Counter()
    # начнем с абсолютного случайно выбранного элемента
    n = np.random.choice(len(vocab))
    for i in range(500): # если долго считается, можно уменьшить число проходов
        
        # c вероятностью random_p 
        # перескакиваем на другой узел
        go_random = np.random.choice([0, 1], p=[1-random_p, random_p])
        if go_random:
            n = np.random.choice(len(vocab))
        
        n = take_step(n, m)
        # записываем узлы, в которых были
        c.update([n])
    
    # вернем топ-N наиболее часто встретившихся сл
    return [id2word[i] for i, count in c.most_common(top)]

def take_step(n, matrix):
    rang = len(matrix[n])
    # выбираем узел из заданного интервала, на основе распределения из матрицы совстречаемости
    next_n = np.random.choice(range(rang), p=matrix[n])
    return next_n

# %%
# %%time
keywords_rw = data['content_norm'].apply(lambda x: get_kws(x, 10, 10))
# Out:
# CPU times: user 1min 10s, sys: 4 ms, total: 1min 10s
# Wall time: 1min 10s

# %%
evaluate(data['keywords'], keywords_rw)
# Out:
# Precision -  0.11
# Recall -  0.21
# F1 -  0.14
# Jaccard -  0.08

# %%
keywords_rw.head(10)
# Out:
# 0             [пора, насилие, цикл, акция, декриминализация, новое, ставрополец, яблоко, власть, виктор]
# 1                           [куб, ямал, миллиард, триллион, страна, год, метр, запас, кубометр, холдинг]
# 2                           [полночь, сериал, рецензия, дата, открытие, витта, земля, роман, книга, мир]
# 3     [монтаж, видеодоказательство, видео, экспертиза, визит, кадр, участник, позиция, свидетель, слово]
# 4               [освоение, тинао, территория, площадь, парка, га, конкурс, забота, пространство, власть]
# 5          [контакт, превышение, р.грожан, гонка, трасса, переговоры, участие, круг, время, отстранение]
# 6                      [34-го, андрей, место, ширман, влияние, избиение, глава, дело, россия, свидетель]
# 7    [расположение, интеллигенция, закон, заместитель, документ, услуга, внесение, сфера, акт, политика]
# 8                        [монархия, сирия, катар, газопровод, европа, турция, россия, год, иран, регион]
# 9                 [рф, округа, житель, участник, исламист, год, ячейка, организация, март, деятельность]
# Name: content_norm, dtype: object

# %% [markdown]
# Попбруем теперь важность считать с помощью какой-нибудь метрики из networkx.

# %%
import networkx as nx

# %%
def build_matrix(text, window_size=5):
    vocab = set(text)
    word2id = {w:i for i, w in enumerate(vocab)}
    id2word = {i:w for i, w in enumerate(vocab)}
    # преобразуем слова в индексы для удобства
    ids = [word2id[word] for word in text]

    # создадим матрицу совстречаемости
    m = np.zeros((len(vocab), len(vocab)))

    # пройдемся окном по всему тексту
    for i in range(0, len(ids), window_size):
        window = ids[i:i+window_size]
        # добавим единичку всем парам слов в этом окне
        for j, k in combinations(window, 2):
            # чтобы граф был ненаправленный 
            m[j][k] += 1
            m[k][j] += 1
    
    return m, id2word

def some_centrality_measure(text, window_size=5, topn=5):
    
    matrix, id2word = build_matrix(text, window_size)
    G = nx.from_numpy_array(matrix)
    # тут можно поставить любую метрику
    node2measure = dict(nx.degree(G))
    
    return [id2word[index] for index,measure in sorted(node2measure.items(), key=lambda x: -x[1])[:topn]]

# %%
# %%time
keyword_nx = data['content_norm'].apply(lambda x: some_centrality_measure(x, 10, 10))
# Out:
# CPU times: user 15.1 s, sys: 32 ms, total: 15.1 s
# Wall time: 15.1 s

# %%
evaluate(data['keywords'], keyword_nx)
# Out:
# Precision -  0.12
# Recall -  0.24
# F1 -  0.16
# Jaccard -  0.09

# %% [markdown]
# Результаты не превосходят tfidf, но и не сильно уступают. Явно можно что-то доработать и превзойти baseline.

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# В семинаре установлен такой бейзлан - F1 -  0.16 (не будем учитывать точность и полноту по отдельности и отбросим жаккара).

# %% [markdown]
# **Ваша задача - предложить 3 способа побить бейзлайн. **

# %% [markdown]
# Нет никаких ограничений кроме:
#
# 1) нельзя изменять метрику
# 2) решение должно быть воспроизводимым

# %% [markdown]
# В качестве ответа нужно предоставить jupyter тетрадку с экспериментами (обязательное условие!) и описать каждую из идей в форме - https://goo.gl/forms/Zb89yjXFr37EITMq1

# %% [markdown]
# Каждый реализованный и описанный способ оценивается в 3 балла. Дополнительный балл можно получить, если способы затрагивают разные аспекты решения (например, первая идея - улучшить нормализацию, вторая - улучшить способ представления текста в виде графа, третья - предложить способ удаления из топа идентичных ключевых слов (рф, россия)).

# %% [markdown]
# Можно использовать мой код как основу, а можно придумать что-то полностью другой.

# %% [markdown]
# Если у вас никак не получается побить бейзлайн вы можете предоставить реализацию и описание неудавшихся экспериментов (каждый оценивается в 0.5 баллов).
